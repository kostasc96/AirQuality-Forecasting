# %%
import pandas as pd
import datetime
import csv

# %%
def data_cleaning_temperature(temp):
    if temp < 0:
        return -1
    elif 0 <= temp <= 5:
        return 0
    elif 6 <= temp <= 10:
        return 1
    elif 11 <= temp <= 15:
        return 2
    elif 16 <= temp <= 25:
        return 3
    elif 26 <= temp <= 30:
        return 4
    elif 31 <= temp <= 40:
        return 5
    else:
        return 6

def data_cleaning_winddirection(degrees):
    if 348.75 <= degrees <= 380 or 0 <= degrees <= 11.25:
        return 'N'
    elif 11.25 < degrees < 33.75:
        return 'NNE'
    elif 33.75 <= degrees <= 56.25:
        return 'NE'
    elif 56.25 < degrees < 78.75:
        return 'ENE'
    elif 78.25 <= degrees <= 101.25:
        return 'E'
    elif 101.25 < degrees < 123.75:
        return 'ESE'
    elif 123.75 <= degrees <= 146.25:
        return 'SE'
    elif 146.25 < degrees < 168.75:
        return 'SSE'
    elif 168.75 <= degrees <= 191.25:
        return 'S'
    elif 191.25 < degrees < 213.75:
        return 'SSW'
    elif 213.75 <= degrees <= 236.25:
        return 'SW'
    elif 236.25 < degrees < 258.75:
        return 'WSW'
    elif 258.75 <= degrees <= 281.25:
        return 'W'
    elif 281.25 < degrees < 303.75:
        return 'WNW'
    elif 303.75 <= degrees <= 326.25:
        return 'NW'
    else:
        return 'NNW'

def data_cleaning_windspeed(speed):
    if speed < 1:
        return 0
    elif 1 <= speed < 6:
        return 1
    elif 6 <= speed < 12:
        return 2
    elif 12 <= speed < 20:
        return 3
    elif 20 <= speed < 29:
        return 4
    elif 29 <= speed < 39:
        return 5
    elif 39 <= speed < 50:
        return 6
    elif 50 <= speed < 62:
        return 7
    elif 62 <= speed < 5:
        return 8
    elif 75 <= speed < 89:
        return 9
    elif 89 <= speed < 103:
        return 10
    elif 103 <= speed < 118:
        return 11
    else:
        return 12

def data_cleaning_humidity(humidity):
    if humidity < 25:
        return 0
    elif 25 <= humidity < 30:
        return 1
    elif 30 <= humidity <= 60:
        return 2
    elif 60 <= humidity < 70:
        return 3
    else:
        return 4

# %%
def weather_df(dataset_weather, output, file_format, file_path):
    tmp_temp = None 
    tmp_humidity = None 
    tmp_winddir = None 
    tmp_windspd = None 
    tmp_pm10 = -9999.0
    dataset_weather = file_path + dataset_weather + '.' + file_format
    weather = pd.read_csv(dataset_weather, sep=',')
    weather['temp_dir'] = ""
    for i, row in weather.iterrows():
        if pd.isna(weather.at[i,'real_temp']) and i > 0:
            weather.at[i,'real_temp'] = tmp_temp
        else:
            tmp_temp = data_cleaning_temperature(int(row.real_temp))
            weather.at[i,'real_temp'] = tmp_temp
        
        if pd.isna(weather.at[i,'real_humidity']) and i > 0:
            weather.at[i,'real_humidity'] = tmp_humidity
        else:
            tmp_humidity = data_cleaning_humidity(row.real_humidity)
            weather.at[i,'real_humidity'] = tmp_humidity
        
        if pd.isna(weather.at[i,'real_winddir']) and i > 0:
            weather.at[i,'temp_dir'] = tmp_winddir
        else:
            tmp_winddir = data_cleaning_winddirection(float(row.real_winddir))
            weather.at[i,'temp_dir'] = tmp_winddir
        
        if pd.isna(weather.at[i,'real_windspd']) and i > 0:
            weather.at[i,'real_windspd'] = tmp_windspd
        else:
            tmp_windspd = data_cleaning_windspeed(row.real_windspd)
            weather.at[i,'real_windspd'] = tmp_windspd
            
        if weather.at[i,'pm10'] ==  -9999.0 and i > 0:
            weather.at[i,'pm10'] = tmp_pm10
        else:
            tmp_pm10 = weather.at[i,'pm10']
        tmp = i
    
    weather = weather.drop(columns=['real_winddir'])
    weather = weather.rename(columns={"temp_dir":"real_winddir"})
    weather.to_csv('CleanFiles/' + output + '.csv')

# %%
weather_df('NeaSmirniClean','NeaSmirniExtract','csv','CleanFiles/')

# %%
weather = pd.read_csv('CleanFiles/NeaSmirniExtract.csv', sep=',')

# %%
weather
# Out:
#        Unnamed: 0            date_time  real_temp  real_humidity  \
# 0               0  2016-01-01 00:00:00        0.0            3.0
# 1               1  2016-01-01 01:00:00        0.0            4.0
# 2               2  2016-01-01 02:00:00       -1.0            4.0
# 3               3  2016-01-01 03:00:00        0.0            3.0
# 4               4  2016-01-01 04:00:00       -1.0            4.0
# ...           ...                  ...        ...            ...
# 35059       35059  2019-12-31 19:00:00        1.0            3.0
# 35060       35060  2019-12-31 20:00:00        1.0            3.0
# 35061       35061  2019-12-31 21:00:00        0.0            4.0
# 35062       35062  2019-12-31 22:00:00        0.0            3.0
# 35063       35063  2019-12-31 23:00:00        0.0            3.0
#
#        real_windspd  station_id  forecast_tempC  forecast_humidity  season  \
# 0               2.0           3               0                  3  Winter
# ...

# %%
weather_df('AgiaParaskeviClean','AgiaParaskeviExtract','csv','CleanFiles/')
weather_df('AristotelousClean','AristotelousExtract','csv','CleanFiles/')
weather_df('AthensClean','AthensExtract','csv','CleanFiles/')
weather_df('ElefsinaClean','ElefsinaExtract','csv','CleanFiles/')
#weather_df('GeoponikiClean','GeoponikiExtract','csv','CleanFiles/')

# %%
weather_df('KoropiClean','KoropiExtract','csv','CleanFiles/')
weather_df('LiosiaClean','LiosiaExtract','csv','CleanFiles/')
weather_df('LykovrisiClean','LykovrisiExtract','csv','CleanFiles/')
weather_df('MarousiClean','MarousiExtract','csv','CleanFiles/')

# %%
weather_df('PatisionClean','PatisionExtract','csv','CleanFiles/')
weather_df('PeristeriClean','PeristeriExtract','csv','CleanFiles/')
weather_df('PireusClean','PireusExtract','csv','CleanFiles/')
weather_df('ThrakomakedonesClean','ThrakomakedonesExtract','csv','CleanFiles/')
